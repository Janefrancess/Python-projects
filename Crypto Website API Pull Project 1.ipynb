# %% [markdown]
# # Automating Crypto Website API Pull

# %%
import json
import ssl
import urllib.parse
import urllib.request

import certifi

params = urllib.parse.urlencode(
    {
        "start": "1",
        "limit": "10",
        "convert": "USD",
    }
)

request = urllib.request.Request(
    f"https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?{params}",
    headers={
        "Accept": "application/json",
        "X-CMC_PRO_API_KEY": "5cb56b8df9474d229b682e099676f279",
    },
)

context = ssl.create_default_context(cafile=certifi.where())

with urllib.request.urlopen(request, context=context) as response:
    data = json.load(response)

print(data)
# Out:
# {'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'infinite_supply': False, 'circulating_supply': 20068818, 'total_supply': 20068818, 'max_supply': 21000000, 'date_added': '2010-07-13T00:00:00.000Z', 'num_market_pairs': 12694, 'cmc_rank': 1, 'last_updated': '2026-08-11T17:38:00.000Z', 'tvl_ratio': None, 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'minted_market_cap': 1274014639694.39, 'quote': {'USD': {'price': 63482.29575326226, 'volume_24h': 21243916698.961926, 'cex_volume_24h': 21220078417.10831, 'dex_volume_24h': 23838281.85361123, 'volume_change_24h': -1.1501, 'percent_change_1h': -0.03587849, 'percent_change_24h': -0.64997981, 'percent_change_7d': -0.91227287, 'percent_change_30d': -0.99738672, 'percent_change_60d': -0.52685564, 'percent_change_90d': -19.96936497, 'market_cap': 1274014639694.3933, 'market_cap_dominance': 58.6236, 'fully_diluted_market_cap': 1333128210818.51, 'tvl': None, 'last_updated': '2026-08-11T17:38:00.000Z'}}, 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'layer-1', 'ftx-bankruptcy-estate', '2017-2018-alt-season', 'us-strategic-crypto-reserve', 'binance-ecosystem', 'binance-listing', 'sec-cftc-token-taxonomy', 'sec-cftc-digital-commodities']}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'infinite_supply': True, 'circulating_supply': 120682035.68761347, 'total_supply': 120682035.68761347, 'max_supply': None, 'date_added': '2015-08-07T00:00:00.000Z', 'num_market_pairs': 12455, 'cmc_rank': 2, 'last_updated': '2026-08-11T17:35:00.000Z', 'tvl_ratio': None, 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'minted_market_cap': 224764128803.33, 'quote': {'USD': {'price': 1862.4489346959042, 'volume_24h': 7644443370.595033, 'cex_volume_24h': 7539571784.936788, 'dex_volume_24h': 104871585.65824187, 'volume_change_24h': -12.7081, 'percent_change_1h': 0.04022881, 'percent_change_24h': -0.63061391, 'percent_change_7d': -0.64755586, 'percent_change_30d': 2.40197796, 'percent_change_60d': 11.59178137, 'percent_change_90d': -17.37135348, 'market_cap': 224764128803.3288, 'market_cap_dominance': 10.3406, 'fully_diluted_market_cap': 224764128803.33, 'tvl': None, 'last_updated': '2026-08-11T17:35:00.000Z'}}, 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'layer-1', 'ftx-bankruptcy-estate', 'sora-ecosystem', 'rsk-rbtc-ecosystem', 'world-liberty-financial-portfolio', 'us-strategic-crypto-reserve', 'binance-ecosystem', 'binance-listing', 'abstract-chain-ecosystem', 'unichain-ecosystem', 'soneium-ecosystem', 'sophon-ecosystem', 'sec-cftc-token-ta ...

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
pd.json_normalize(data['data'])
# Out:
#       id         name symbol         slug  infinite_supply  \
# 0      1      Bitcoin    BTC      bitcoin            False
# 1   1027     Ethereum    ETH     ethereum             True
# 2    825  Tether USDt   USDT       tether             True
# 3   1839          BNB    BNB          bnb            False
# 4   3408         USDC   USDC     usd-coin            False
# 5     52          XRP    XRP          xrp            False
# 6   5426       Solana    SOL       solana             True
# 7   1958         TRON    TRX         tron             True
# 8  32196  Hyperliquid   HYPE  hyperliquid            False
# 9     74     Dogecoin   DOGE     dogecoin             True
#
#    circulating_supply  total_supply    max_supply                date_added  \
# 0        2.006882e+07  2.006882e+07  2.100000e+07  2010-07-13T00:00:00.000Z
# 1        1.206820e+08  1.206820e+08           NaN  2015-08-07T00:00:00.000Z
# 2        1.832188e+11  1.883449e+11           NaN  2015-02-25T00:00:00.000Z
# 3        1.331642e+08  1.331642e+08  1.331642e+08  2017-07-25T00:00:00.000Z
# 4        7.217839e+10  7.217839e+10           NaN  2018-10-08T00:00:00.000Z
# 5        6.253327e+10  9.998564e+10  1.000000e+11  2013-08-04T00:00:00.000Z
# 6        5.824814e+08  6.320094e+08           NaN  2020-04-10T00:00:00.000Z
# 7        9.489836e+10  9.489836e+10           NaN  2017-09-13T00:00:00.000Z
# 8        2.526742e+08  9.527027e+08  9.527027e+08  2024-07-15T10:14:50.000Z
# 9        1.554508e+11  1.554508e+11           NaN  2013-12-15T00:00:00.000Z
#
#    num_market_pairs  cmc_rank              last_updated tvl_ratio  platform  \
# 0             12694         1  2026-08-11T17:38:00.000Z      None       NaN
# 1             12455         2  2026-08-11T17:35:00.000Z      None       NaN
# 2            193972         3  2026-08-11T17:37:00.000Z      None       NaN
# 3              3344         4  2026-08-11T17:37:00.000Z      None       NaN
# 4             42992         5  2026-08-11T17:37:00.000Z      None       NaN
# 5              1856         6  2026-08-11T17:38:00.000Z      None       NaN
# 6              1152         7  2026-08-11T17:35:00.000Z      None       NaN
# 7              1358         8  2026-08-11T17:38:00.000Z      None       NaN
# 8               305         9  2026-08-11T17:37:00.000Z      None       NaN
# 9              1464        10  2026-08-11T17:37:00.000Z      None       NaN
#
#    self_reported_circulating_supply  self_reported_market_cap  \
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                      6.090122e+10              6.088596e+10
# 5                               NaN                       NaN
# 6                      5.252369e+08              3.938530e+10
# 7                      9.466789e+10              3.167911e+10
# 8                      3.339317e+08              1.799956e+10
# 9                               NaN                       NaN
#
#    minted_market_cap                                               tags  \
# 0       1.274015e+12  [mineable, pow, sha-256, store-of-value, state...
# 1       2.247641e+11  [pos, smart-contracts, ethereum-ecosystem, coi...
# 2       1.881586e+11  [stablecoin, asset-backed-stablecoin, usd-stab...
# 3       8.115389e+10  [marketplace, centralized-exchange, payments, ...
# 4       7.216030e+10  [medium-of-exchange, stablecoin, asset-backed-...
# 5       1.013634e+11  [medium-of-exchange, enterprise-solutions, xrp...
# 6       4.739173e+10  [pos, platform, solana-ecosystem, cms-holdings...
# 7       3.175623e+10  [media, payments, tron-ecosystem, layer-1, dwf...
# 8       5.135252e+10  [decentralized-exchange-dex-token, defi, deriv...
# 9       1.101734e+10  [mineable, pow, scrypt, medium-of-exchange, me...
#
#    quote.USD.price  quote.USD.volume_24h  quote.USD.cex_volume_24h  \
# 0     63482.295753          2.124392e+10              2.122008e+10
# 1      1862.448935          7.644443e+09              7.539572e+09
# 2         0.999011          4.602344e+10              4.486908e+10
# 3       609.427081          1.198925e+09              1.180714e+09
# 4         0.999749          7.153315e+09              6.216003e+09
# 5         1.013780          1.356142e+09              1.355041e+09
# 6        74.985791          1.324919e+09              1.324900e+09
# 7         0.334634          5.319030e+08              5.318280e+08
# 8        53.901930          2.067403e+08              1.839508e+08
# 9         0.070873          3.787119e+08              3.783946e+08
#
#    quote.USD.dex_volume_24h  quote.USD.volume_change_24h  \
# 0              2.383828e+07                      -1.1501
# 1              1.048716e+08                     -12.7081
# 2              1.154362e+09                      -1.7783
# 3              1.821118e+07                       4.5202
# 4              9.373120e+08                      -7.5526
# 5              1.101134e+06                      19.0947
# 6              1.896764e+04                     -11.2404
# 7              7.495026e+04                     -38.4391
# 8              2.278943e+07                      -5.7313
# 9              3.172816e+05                      -8.7831
#
#    quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                    -0.035878                     -0.649980
# 1                     0.040229                     -0.630614
# 2                    -0.008984                      0.008718
# 3                     0.055515                      1.619723
# 4                    -0.006540                     -0.009357
# 5                     0.656634                     -0.655372
# 6                     0.141991                     -1.224038
# 7                     0.017969                      1.161057
# 8                    -0.131052                     -2.070052
# 9                     0.510848                      1.672669
#
#    quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                    -0.912273                     -0.997387
# 1                    -0.647556                      2.401978
# 2                    -0.017262                     -0.036637
# 3                     2.784839                      5.157112
# 4                    -0.016245                     -0.011030
# 5                    -5.771791                     -7.790949
# 6                     1.272284                     -3.128125
# 7                     1.586329                      1.076514
# 8                    -3.029432                    -20.699913
# 9                     0.743685                     -3.626130
#
#    quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                     -0.526856                    -19.969365
# 1                     11.591781                    -17.371353
# 2                     -0.034594                     -0.050344
# 3                      0.533410                     -8.973381
# 4                      0.006547                     -0.005971
# 5                    -10.421926                    -28.992997
# 6                     11.019408                    -17.438752
# 7                      6.531487                     -4.557113
# 8                    -13.393947                     37.657139
# 9                    -19.722527                    -37.042880
#
#    quote.USD.market_cap  quote.USD.market_cap_dominance  \
# 0          1.274015e+12                         58.6236
# 1          2.247641e+11                         10.3406
# 2          1.830375e+11                          8.4209
# 3          8.115389e+10                          3.7336
# 4          7.216030e+10                          3.3198
# 5          6.339497e+10                          2.9171
# 6          4.367783e+10                          2.0095
# 7          3.175623e+10                          1.4613
# 8          1.361963e+10                          0.6266
# 9          1.101734e+10                          0.5069
#
#    quote.USD.fully_diluted_market_cap quote.USD.tvl    quote.USD.last_updated  \
# 0                        1.333128e+12          None  2026-08-11T17:38:00.000Z
# 1                        2.247641e+11          None  2026-08-11T17:35:00.000Z
# 2                        1.881586e+11          None  2026-08-11T17:37:00.000Z
# 3                        8.115389e+10          None  2026-08-11T17:37:00.000Z
# 4                        7.216030e+10          None  2026-08-11T17:37:00.000Z
# 5                        1.013780e+11          None  2026-08-11T17:38:00.000Z
# 6                        4.739173e+10          None  2026-08-11T17:35:00.000Z
# 7                        3.175623e+10          None  2026-08-11T17:38:00.000Z
# 8                        5.135252e+10          None  2026-08-11T17:37:00.000Z
# 9                        1.101734e+10          None  2026-08-11T17:37:00.000Z
#
#    platform.id platform.slug platform.name platform.symbol  \
# 0          NaN           NaN           NaN             NaN
# 1          NaN           NaN           NaN             NaN
# 2       1027.0      ethereum      Ethereum             ETH
# 3          NaN           NaN           NaN             NaN
# 4      24091.0        zksync    zkSync Era              ZK
# 5          NaN           NaN           NaN             NaN
# 6          NaN           NaN           NaN             NaN
# 7          NaN           NaN           NaN             NaN
# 8      32196.0   hyperliquid   Hyperliquid            HYPE
# 9          NaN           NaN           NaN             NaN
#
#                        platform.token_address
# 0                                         NaN
# 1                                         NaN
# 2  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3                                         NaN
# 4  0x1d17CBcF0D6D143135aE902365D2E5e2A16538D4
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8          0x0d01dc56dcaaca66ad901c959b4011ec
# 9                                         NaN
